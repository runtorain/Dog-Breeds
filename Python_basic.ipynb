# %% [markdown]
# <a href="https://colab.research.google.com/github/runtorain/Dog-Breeds/blob/main/Python_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Basic Operation

# %%
1+4
# Out:
# 5

# %%
2-1
# Out:
# 1

# %%
2**3
# Out:
# 8

# %%
# !pwd
# Out:
# /content

# %%
print(1+1)
# Out:
# 2

# %%
my_income =100
tax_rate =0.1

my_texts =my_income*tax_rate
print(my_texts)
# Out:
# 10.0

# %% [markdown]
# ##String

# %%
a = "Hello"
b= "Honda"

# %%
print(b)
# Out:
# Honda

# %%
my_var = "I don\'t want to go "
print(my_var)
# Out:
# I don't want to go

# %% [markdown]
# ##Method

# %%
print(my_var.upper())
# Out:
# I DON'T WANT TO GO

# %%
my_var2 = "Hello Mike how is your dog"

# %%
print(my_var2.split())
# Out:
# ['Hello', 'Mike', 'how', 'is', 'your', 'dog']

# %%
print(my_var2.split("o"))
# Out:
# ['Hell', ' Mike h', 'w is y', 'ur d', 'g']

# %% [markdown]
# ###Index for string

# %%
print(my_var2[0])
# Out:
# H

# %%
print(my_var2[15])
# Out:
# i

# %%
print(my_var2[-1])
# Out:
# g

# %%
print(my_var2[0:5])
# Out:
# Hell

# %%
print(my_var2[3:])
# Out:
# lo Mike how is your dog

# %%
first_name = "ฑ๊ฒยา"
last_name = "ประจิมเวศ"

print(f"สวัสดี {first_name} , {last_name}")
# Out:
# สวัสดี ฑ๊ฒยา , ประจิมเวศ

# %% [markdown]
# ### List in Python

# %%
my_var = 10
my_list = [1,2,3,my_var]

print(my_list)
# Out:
# [1, 2, 3, 10]

# %%
my_list2 = [100,200,300,400,500]

print(my_list2[0])
# Out:
# 100

# %%
print(my_list2[1:3])
# Out:
# [200, 300]

# %%
my_list2.append(600)

# %%
print(my_list2)
# Out:
# [100, 200, 300, 400, 500, 600]

# %%
my_list2.pop()
# Out:
# 600

# %%
print(my_list2)
# Out:
# [100, 200, 300, 400, 500]

# %%
my_list2.pop(1)
# Out:
# 200

# %%
print(my_list2)
# Out:
# [100, 300, 400, 500]

# %%
my_list2.reverse()

# %%
print(my_list2)
# Out:
# [500, 400, 300, 100]

# %%
my_list2.sort()

# %%
print(my_list2)
# Out:
# [100, 300, 400, 500]

# %% [markdown]
# ##Dictionary
